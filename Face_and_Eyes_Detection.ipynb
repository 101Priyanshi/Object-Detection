# %% [markdown]
# ### Importing Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Creating Classifiers

# %%
eye_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_eye.xml')
face_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')

# %% [markdown]
# ### Open Image

# %%
image = cv2.imread('Images/eye_face.jpg')

# %% [markdown]
# ### Fix Image

# %%
fix_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Face Classifier

# %%
faces = face_classifier.detectMultiScale(fix_img, 1.3, 5)# 1.3 is scaleFactor and 5 is min_neighbors

# %% [markdown]
# ### If No Face Detected

# %%
if faces is ():
    print("No faces found")

# %% [markdown]
# ### Final Results

# %%
def detect_face_eyes(fix_img):
    face_rects = face_classifier.detectMultiScale(fix_img)
    for(x,y,z,h) in face_rects:
        cv2.rectangle(fix_img,
                     (x,y),#upper left corner
                     (x+z,y+h),#down right corner
                     (255,0,0),#red color
                     8)#thickness
        eye_rects = eye_classifier.detectMultiScale(fix_img)
        for(ix,iy,iz,ih) in eye_rects:
            cv2.rectangle(fix_img,
                     (ix,iy),#upper left corner
                     (ix+iz,iy+ih),#down right corner
                     (0,255,0),#red color
                     6)#thickness
    return fix_img

# %%
result = detect_face_eyes(fix_img)
plt.imshow(result)
